# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# # Import the data
# car_data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m12/lesson_1/datasets/car-data-encoded.csv")
# car_data

# Read in the CSV file as a pandas DataFrame and set the "year" column as the index.
df = pd.read_csv('Resources/model_car_prices.csv')

# Review the DataFrame
df.head()
# Out:
#    odometer       mmr  year  make  body  color  interior  sellingprice  \
# 0 -1.034279  0.814387  2015    24     6     17         1       21500.0
# 1 -1.592749  0.831860  2015    24     6     17         0       21500.0
# 2 -3.501281  1.346200  2014     3     7      8         1       30000.0
# 3 -1.183471  1.167695  2015    52     7     17         1       27750.0
# 4 -2.832010  2.220625  2014     3     7      8         1       67000.0
#
#    automatic
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True

# %%
# # Drop na rows
# car_data = car_data.dropna()
print(list(df.columns))
# Out:
# ['odometer', 'mmr', 'year', 'make', 'body', 'color', 'interior', 'sellingprice', 'automatic']

# %% [markdown]
# ## Split into training and testing sets

# %%
# Features to include: "make", "fuel-type", "num-of-doors", "drive-wheels",
# "length", "width", "height", "engine-size", "fuel-system", "city-mpg"
features = ['odometer', 'mmr', 'year', 'make', 'body', 'color', 'interior', 'automatic']

X = df[features]
X.head()
# Out:
#    odometer       mmr  year  make  body  color  interior  automatic
# 0 -1.034279  0.814387  2015    24     6     17         1       True
# 1 -1.592749  0.831860  2015    24     6     17         0       True
# 2 -3.501281  1.346200  2014     3     7      8         1       True
# 3 -1.183471  1.167695  2015    52     7     17         1       True
# 4 -2.832010  2.220625  2014     3     7      8         1       True

# %%
features = target.index.drop('sellingprice')

# %%
# Set the target variable y
y = df["sellingprice"]

# %%
# Now split the data into training and testing sets again
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Train the model

# %%
# Create the model
model = LinearRegression()

# Fit the model to the training data. 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluate the model

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"mean squared error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
# Out:
# mean squared error (MSE): 25162851.584073503
# R-squared (R2): 0.7218090226158771

# %%
# Call the `score()` method on the model to show the R2 score
model.score(X_test, y_test)
# Out:
# 0.7218090226158771

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Create a correlation matrix
corr_matrix = df.corr()

# Set the plot size, color, and font scale
sns.set(font_scale=1)
plt.figure(facecolor='gray', figsize=(10, 8))

# Display the matrix without annotations
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.show()

# %%
# Set the plot size and color
plt.figure(facecolor='gray', figsize=(15,8))
ax = plt.axes()
ax.set_facecolor("gray")


# Display a plot of Target correlations
target = corr_matrix['sellingprice']
target.plot(kind='bar')
plt.show()

# %%
# Set the plot size and color
plt.figure(facecolor='gray', figsize=(10,8))
ax = plt.axes()
ax.set_facecolor("gray")


# Display a plot of Target correlations
target = corr_matrix['sellingprice']
Key = (target > 0.1) | (target < -0.1)
target = target[Key]
target.plot(kind='bar')
plt.show()

# %%
Key = (target > 0.1) | (target < -0.1)
target[Key]
# Out:
# odometer       -0.487416
# mmr             0.834878
# year            0.580584
# body           -0.179328
# interior       -0.154893
# sellingprice    1.000000
# Name: sellingprice, dtype: float64

# %%
target.index.drop('sellingprice')
# Out:
# Index(['odometer', 'mmr', 'year', 'body', 'interior'], dtype='object')
