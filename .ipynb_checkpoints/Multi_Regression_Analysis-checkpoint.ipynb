# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
# Read in the CSV file as a pandas DataFrame
df = pd.read_csv('Resources/model_car_prices.csv')

# Review the DataFrame
df.head()
# Out:
#    odometer       mmr  year  make  body  color  interior  sellingprice  \
# 0 -0.978981  0.742349  2015    18     6     17         1       21500.0
# 1 -1.117920  0.774673  2015    18     6     17         0       21500.0
# 2 -1.272506  1.970637  2014     2     7      8         1       30000.0
# 3 -1.024175  1.496561  2015    40     7     17         1       27750.0
# 4 -1.247387  5.644724  2014     2     7      8         1       67000.0
#
#    automatic
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True

# %%
# Create a correlation matrix
corr_matrix = df.corr()

# Set the plot size, color, and font scale
sns.set(font_scale=1)
plt.figure(facecolor='gray', figsize=(10, 8))

# Display the matrix without annotations
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.show()

# %%
# Set the plot size and color
plt.figure(facecolor='gray', figsize=(15,8))
ax = plt.axes()
ax.set_facecolor("gray")


# Display a plot of Target correlations
target = corr_matrix['sellingprice']
target.plot(kind='bar')
plt.show()

# %%
Key = (target > 0.1) | (target < -0.1)
target[Key]
# Out:
# odometer       -0.583588
# mmr             0.983025
# year            0.590049
# body           -0.177437
# interior       -0.156996
# sellingprice    1.000000
# Name: sellingprice, dtype: float64

# %%
# Features to include: 'odometer', 'mmr', 'year', 'make', 'body', 'color', 'interior', 'automatic'

features = ['odometer', 'mmr', 'year', 'make', 'body', 'color', 'interior', 'automatic']

# features = ['odometer', 'year', 'mmr', 'make', 'body', 'color', 'interior', 'automatic']

X = df[features]
X.head()
# Out:
#    odometer       mmr  year  make  body  color  interior  automatic
# 0 -0.978981  0.742349  2015    18     6     17         1       True
# 1 -1.117920  0.774673  2015    18     6     17         0       True
# 2 -1.272506  1.970637  2014     2     7      8         1       True
# 3 -1.024175  1.496561  2015    40     7     17         1       True
# 4 -1.247387  5.644724  2014     2     7      8         1       True

# %%
# Set the target variable y
y = df["sellingprice"]

# %%
# Now split the data into training and testing sets again
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create the model
model = LinearRegression()

# Fit the model to the training data. 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"mean squared error (MSE) including MMR: {mse:.4f}")
print(f"R-squared (R2) including MMR: {r2:.4f}")
# Out:
# mean squared error (MSE) including MMR: 3178083.7117
# R-squared (R2) including MMR: 0.9638

# %%
# Features to include: 'odometer', 'year', 'make', 'body', 'color', 'interior', 'automatic'

features_no_mmr = ['odometer', 'year', 'make', 'body', 'color', 'interior', 'automatic']

X = df[features_no_mmr]
X.head()
# Out:
#    odometer  year  make  body  color  interior  automatic
# 0 -0.978981  2015    18     6     17         1       True
# 1 -1.117920  2015    18     6     17         0       True
# 2 -1.272506  2014     2     7      8         1       True
# 3 -1.024175  2015    40     7     17         1       True
# 4 -1.247387  2014     2     7      8         1       True

# %%
# Set the target variable y
y = df["sellingprice"]

# %%
# Now split the data into training and testing sets again
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create the model
model = LinearRegression()

# Fit the model to the training data. 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"mean squared error (MSE) excluding MMR: {mse:.4f}")
print(f"R-squared (R2) excluding MMR: {r2:.4f}")
# Out:
# mean squared error (MSE) excluding MMR: 49583493.7931
# R-squared (R2) excluding MMR: 0.4357
