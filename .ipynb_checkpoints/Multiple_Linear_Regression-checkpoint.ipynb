# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# # Import the data
# car_data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m12/lesson_1/datasets/car-data-encoded.csv")
# car_data

# Read in the CSV file as a pandas DataFrame and set the "year" column as the index.
df = pd.read_csv("Resources/model_car_prices.csv")

# Review the DataFrame
df.head()
# Out:
#    year  odometer      mmr  sellingprice  make_Acura  make_Aston Martin  \
# 0  2015   16639.0  20500.0       21500.0       False              False
# 1  2015    9393.0  20800.0       21500.0       False              False
# 2  2014    1331.0  31900.0       30000.0       False              False
# 3  2015   14282.0  27500.0       27750.0       False              False
# 4  2014    2641.0  66000.0       67000.0       False              False
#
#    make_Audi  make_BMW  make_Bentley  make_Buick  ...  interior_gold  \
# 0      False     False         False       False  ...          False
# 1      False     False         False       False  ...          False
# 2      False      True         False       False  ...          False
# 3      False     False         False       False  ...          False
# 4      False      True         False       False  ...          False
#
#    interior_gray  interior_green  interior_orange  interior_purple  \
# ...

# %%
# # Drop na rows
# car_data = car_data.dropna()
print(list(df.columns))
# Out:
# ['year', 'odometer', 'mmr', 'sellingprice', 'make_Acura', 'make_Aston Martin', 'make_Audi', 'make_BMW', 'make_Bentley', 'make_Buick', 'make_Cadillac', 'make_Chevrolet', 'make_Chrysler', 'make_Daewoo', 'make_Dodge', 'make_FIAT', 'make_Ferrari', 'make_Fisker', 'make_Ford', 'make_GMC', 'make_Geo', 'make_HUMMER', 'make_Honda', 'make_Hyundai', 'make_Infiniti', 'make_Isuzu', 'make_Jaguar', 'make_Jeep', 'make_Kia', 'make_Lamborghini', 'make_Land Rover', 'make_Lexus', 'make_Lincoln', 'make_Lotus', 'make_MINI', 'make_Maserati', 'make_Mazda', 'make_Mercedes-Benz', 'make_Mercury', 'make_Mitsubishi', 'make_Nissan', 'make_Oldsmobile', 'make_Plymouth', 'make_Pontiac', 'make_Porsche', 'make_Ram', 'make_Rolls-Royce', 'make_Saab', 'make_Saturn', 'make_Scion', 'make_Smart', 'make_Subaru', 'make_Suzuki', 'make_Tesla', 'make_Toyota', 'make_Volkswagen', 'make_Volvo', 'body_Convertible', 'body_Coupe', 'body_Crew_Truck', 'body_Ext_Truck', 'body_Hatchback', 'body_Minivan', 'body_SUV', 'body_Sedan', 'body_Tr
# ...

# %% [markdown]
# ## Split into training and testing sets

# %%
# Features to include: "make", "fuel-type", "num-of-doors", "drive-wheels",
# "length", "width", "height", "engine-size", "fuel-system", "city-mpg"
# features = ['year', 'odometer', 'mmr', 'sellingprice', 'make_Acura', 'make_Aston Martin', 'make_Audi', 'make_BMW', 'make_Bentley', 'make_Buick', 'make_Cadillac', 'make_Chevrolet', 'make_Chrysler', 'make_Daewoo', 'make_Dodge', 'make_FIAT', 'make_Ferrari', 'make_Fisker', 'make_Ford', 'make_GMC', 'make_Geo', 'make_HUMMER', 'make_Honda', 'make_Hyundai', 'make_Infiniti', 'make_Isuzu', 'make_Jaguar', 'make_Jeep', 'make_Kia', 'make_Lamborghini', 'make_Land Rover', 'make_Lexus', 'make_Lincoln', 'make_Lotus', 'make_MINI', 'make_Maserati', 'make_Mazda', 'make_Mercedes-Benz', 'make_Mercury', 'make_Mitsubishi', 'make_Nissan', 'make_Oldsmobile', 'make_Plymouth', 'make_Pontiac', 'make_Porsche', 'make_Ram', 'make_Rolls-Royce', 'make_Saab', 'make_Saturn', 'make_Scion', 'make_Smart', 'make_Subaru', 'make_Suzuki', 'make_Tesla', 'make_Toyota', 'make_Volkswagen', 'make_Volvo', 'body_Convertible', 'body_Coupe', 'body_Crew_Truck', 'body_Ext_Truck', 'body_Hatchback', 'body_Minivan', 'body_SUV', 'body_Sedan', 'body_Truck', 'body_Van', 'body_Wagon', 'transmission_automatic', 'transmission_manual', 'color_beige', 'color_black', 'color_blue', 'color_brown', 'color_burgundy', 'color_charcoal', 'color_cream', 'color_gold', 'color_gray', 'color_green', 'color_lime', 'color_orange', 'color_pink', 'color_purple', 'color_red', 'color_silver', 'color_turquoise', 'color_white', 'color_yellow', 'interior_beige', 'interior_black', 'interior_blue', 'interior_brown', 'interior_burgundy', 'interior_cream', 'interior_gold', 'interior_gray', 'interior_green', 'interior_orange', 'interior_purple', 'interior_red', 'interior_silver', 'interior_tan', 'interior_white', 'interior_yellow']

features = target.index.drop('sellingprice')

X = df[features]
X.head()
# Out:
#    year  odometer      mmr  make_BMW  make_Infiniti  make_Land Rover  \
# 0  2015   16639.0  20500.0     False          False            False
# 1  2015    9393.0  20800.0     False          False            False
# 2  2014    1331.0  31900.0      True          False            False
# 3  2015   14282.0  27500.0     False          False            False
# 4  2014    2641.0  66000.0      True          False            False
#
#    make_Lexus  make_Mercedes-Benz  make_Porsche  make_Ram  body_Crew_Truck  \
# 0       False               False         False     False            False
# 1       False               False         False     False            False
# 2       False               False         False     False            False
# 3       False               False         False     False            False
# 4       False               False         False     False            False
#
#    body_SUV  body_Sedan  color_black  interior_black  interior_gray
# ...

# %%
# Set the target variable y
y = df["sellingprice"]

# %%
# Now split the data into training and testing sets again
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ## Train the model

# %%
# Create the model
model = LinearRegression()

# Fit the model to the training data. 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluate the model

# %%
# Calculate the mean_squared_error and the r-squared value
# for the testing data

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"mean squared error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
# Out:
# mean squared error (MSE): 2836217.4510625326
# R-squared (R2): 0.9686438517451502

# %%
# Call the `score()` method on the model to show the R2 score
model.score(X_test, y_test)
# Out:
# 0.9686438517451502

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a correlation matrix
corr_matrix = df.corr()


# Set the plot size, color, and font scale
sns.set(font_scale=1)
plt.figure(facecolor='gray', figsize=(10,8))


# Display the matrix
sns.heatmap(corr_matrix, annot=True, fmt='.0', cmap='coolwarm')
plt.show()

# %%
# Set the plot size and color
plt.figure(facecolor='gray', figsize=(15,8))
ax = plt.axes()
ax.set_facecolor("gray")


# Display a plot of Target correlations
target = corr_matrix['sellingprice']
target.plot(kind='bar')
plt.show()

# %%
# Set the plot size and color
plt.figure(facecolor='gray', figsize=(10,8))
ax = plt.axes()
ax.set_facecolor("gray")


# Display a plot of Target correlations
target = corr_matrix['sellingprice']
Key = (target > 0.1) | (target < -0.1)
target = target[Key]
target.plot(kind='bar')
plt.show()

# %%
Key = (target > 0.1) | (target < -0.1)
target[Key]
# Out:
# year                  0.580584
# odometer             -0.577492
# mmr                   0.983447
# sellingprice          1.000000
# make_BMW              0.139029
# make_Infiniti         0.126402
# make_Land Rover       0.111730
# make_Lexus            0.107399
# make_Mercedes-Benz    0.123598
# make_Porsche          0.136447
# make_Ram              0.116918
# body_Crew_Truck       0.182231
# body_SUV              0.152303
# body_Sedan           -0.175443
# color_black           0.106317
# interior_black        0.183857
# interior_gray        -0.189313
# Name: sellingprice, dtype: float64

# %%
target.index.drop('sellingprice')
# Out:
# Index(['year', 'odometer', 'mmr', 'make_BMW', 'make_Infiniti',
#        'make_Land Rover', 'make_Lexus', 'make_Mercedes-Benz', 'make_Porsche',
#        'make_Ram', 'body_Crew_Truck', 'body_SUV', 'body_Sedan', 'color_black',
#        'interior_black', 'interior_gray'],
#       dtype='object')
